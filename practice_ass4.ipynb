# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('final_preprocessed_dataset.csv')

# %%
print("Source: final_preprocessed_dataset.csv (sampled from Kaggle Sentiment Analysis for Mental Health)")
print("Language: English")
print(f"Dataset size: {data.shape[0]:,} rows, {data.shape[1]} columns")
print("\nLabels:", data['Sentiment'].unique().tolist())
print("\nClass distribution:")
print(data['Sentiment'].value_counts(normalize=True).round(4)*100)

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=data, y='Sentiment', order=data['Sentiment'].value_counts().index)
plt.title('Class Distribution (Imbalanced)')
plt.show()
print("Note: Dataset is moderately imbalanced. Macro-F1 will be the primary metric.")

# %%
data.head()

# %% [markdown]
# ### 4.2

# %%
train_df = data[data['split'] == 'train'].reset_index(drop=True)
val_df   = data[data['split'] == 'val'].reset_index(drop=True)
test_df  = data[data['split'] == 'test'].reset_index(drop=True)
 
X_train_tfidf, y_train = train_df['cleaned_tfidf'], train_df['label']
X_val_tfidf,   y_val   = val_df['cleaned_tfidf'],   val_df['label']
X_test_tfidf,  y_test  = test_df['cleaned_tfidf'],  test_df['label']
 
X_train_bert = train_df['cleaned_bert']
X_val_bert   = val_df['cleaned_bert']
X_test_bert  = test_df['cleaned_bert']
 
print(f"Train : {len(train_df)} | Val : {len(val_df)} | Test : {len(test_df)}")
print(f"Train class distribution: {dict(y_train.value_counts().sort_index())}")
 
# Final preview
print("\\n=== Modelling-Ready Preview (train set, 5 rows) ===")
train_df[['cleaned_tfidf', 'cleaned_bert', 'label']].head(5)
